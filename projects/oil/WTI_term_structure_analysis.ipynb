# %% [markdown]
# # WTI Crude Oil Term Structure
#
# We daily collect free EOD data for WTI Crude oil Futures and upload them into a databse. Once we have sufficient amount of data we will proceed with the analysis

# %%
#importing base packages
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
import os
import glob
import sqlite3

# %%
db_path = "../../db/WTI_futures.db"  
table_name = "WTI_futures_data"

# Connect and read into a DataFrame
conn = sqlite3.connect(db_path)
df = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)
conn.close()

# %%
df
# Out:
#          contract_id  close  change   open   high    low  previous  volume  \
# 0       CLY00 (Cash)  65.37   -1.84   0.00  65.37  65.37     67.21       0
# 1    CLU25 (Sep '25)  65.31   -0.64  65.77  65.86  64.82     65.95  258298
# 2    CLV25 (Oct '25)  64.46   -0.56  64.84  64.95  64.00     65.02  135633
# 3    CLX25 (Nov '25)  63.89   -0.53  64.25  64.35  63.47     64.42   81243
# 4    CLZ25 (Dec '25)  63.49   -0.50  63.85  63.95  63.09     63.99  102265
# ..               ...    ...     ...    ...    ...    ...       ...     ...
# 122  CLV35 (Oct '35)  59.80   -0.45   0.00  59.80  59.80     60.25       0
# 123  CLX35 (Nov '35)  59.74   -0.45   0.00  59.74  59.74     60.19       0
# 124  CLZ35 (Dec '35)  59.67   -0.45   0.00  59.67  59.67     60.12       0
# 125  CLF36 (Jan '36)  59.60   -0.45   0.00  59.60  59.60     60.05       0
# 126  CLG36 (Feb '36)  59.54   -0.45   0.00  59.54  59.54     59.99       0
#
#      open_interest                 date
# 0                0  2025-07-22 00:00:00
# 1           380321  2025-07-22 00:00:00
# 2           238748  2025-07-22 00:00:00
# 3           133633  2025-07-22 00:00:00
# 4           243591  2025-07-22 00:00:00
# ..             ...                  ...
# 122              0  2025-07-22 00:00:00
# 123              0  2025-07-22 00:00:00
# 124              0  2025-07-22 00:00:00
# 125              0  2025-07-22 00:00:00
# 126              5  2025-07-22 00:00:00
#
# [127 rows x 10 columns]
